# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests

# Import API key
from api_keys import geoapify_key

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
city_data_df = pd.read_csv("../output_data/cities.csv")

# Display sample data
city_data_df.head()
# Out:
#    City_ID         City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        0         faya  18.3851   42.4509     22.06        35          21
# 1        1      farsund  58.0948    6.8047     13.30       100           0
# 2        2  new norfolk -42.7826  147.0587     11.72        58          12
# 3        3    jamestown  42.0970  -79.2353      5.77        77         100
# 4        4      lanzhou  36.0564  103.7922     14.53        48          59
#
#    Wind Speed Country        Date
# 0        2.60      SA  1666108228
# 1        7.65      NO  1666108228
# 2        1.34      AU  1666108230
# 3        9.77      US  1666107934
# 4        1.20      CN  1666108230

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
# %%capture --no-display

# Configure the map plot
map_plot_1 = city_data_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    tiles = "OSM",
    size = "Humidity",
    scale = 1,
    color = "City"
)

# Display the map
map_plot_1

##unable to get projection to work
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# c:\Users\Junior\anaconda3\lib\site-packages\hvplot\util.py in process_crs(crs)
#     232         import cartopy.crs as ccrs
# --> 233         import geoviews as gv # noqa
#     234         import pyproj
#
# c:\Users\Junior\anaconda3\lib\site-packages\geoviews\__init__.py in <module>
#       8
# ----> 9 from .annotators import annotate # noqa (API import)
#      10 from .element import ( # noqa (API import)
#
# c:\Users\Junior\anaconda3\lib\site-packages\geoviews\annotators.py in <module>
#      14 from .links import VertexTableLink, PointTableLink, HvRectanglesTableLink, RectanglesTableLink
# ---> 15 from .operation import project
#      16 from .streams import PolyVertexDraw, PolyVertexEdit
#
# c:\Users\Junior\anaconda3\lib\site-packages\geoviews\operation\__init__.py in <module>
#       6 from ..element import _Element
# ----> 7 from .projection import ( # noqa (API import)
#       8     project_image, project_path, project_shape, project_points,
#
# c:\Users\Junior\anaconda3\lib\site-packages\geoviews\operation\projection.py in <module>
#      14
# ---> 15 from ..data import GeoPandasInterface
#      16 from ..element import (Image, Shape, Polygons, Path, Points, Contours,
#
# c:\Users\Junior\anaconda3\lib\site-packages\geoviews\data\__init__.py in <module>
#       1 from .geom_dict import GeomDictInterface # noqa (API import)
# ----> 2 from .geopandas import GeoPandasInterface # noqa (API import)
#       3 from .iris import CubeInterface # noqa (API import)
#
# c:\Users\Junior\anaconda3\lib\site-packages\geoviews\data\geopandas.py in <module>
#       9 from holoviews.core.util import isscalar, unique_iterator, unique_array
# ---> 10 from holoviews.core.data import Dataset, Interface, MultiInterface, PandasAPI
#      11 from holoviews.core.data.interface import DataError
#
# ImportError: cannot import name 'PandasAPI' from 'holoviews.core.data' (c:\Users\Junior\anaconda3\lib\site-packages\holoviews\core\data\__init__.py)
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13992\3715634100.py in <module>
#       1 # Configure the map plot
# ----> 2 map_plot_1 = city_data_df.hvplot.points(
#       3     "Lng",
#       4     "Lat",
#       5     geo = True,
#
# c:\Users\Junior\anaconda3\lib\site-packages\hvplot\plotting\core.py in points(self, x, y, **kwds)
#     520             The HoloViews representation of the plot.
#     521         """
# --> 522         return self(x, y, kind='points', **kwds)
#     523
#     524     def vectorfield(self, x=None, y=None, angle=None, mag=None, **kwds):
#
# c:\Users\Junior\anaconda3\lib\site-packages\hvplot\plotting\core.py in __call__(self, x, y, kind, **kwds)
#      80                 return pn.panel(plot, **panel_dict)
#      81
# ---> 82         return self._get_converter(x, y, kind, **kwds)(kind, x, y)
#      83
#      84     def _get_converter(self, x=None, y=None, kind=None, **kwds):
#
# c:\Users\Junior\anaconda3\lib\site-packages\hvplot\plotting\core.py in _get_converter(self, x, y, kind, **kwds)
#      87         y = y or params.pop('y', None)
#      88         kind = kind or params.pop('kind', None)
# ---> 89         return HoloViewsConverter(
#      90             self._data, x, y, kind=kind, **params
#      91         )
#
# c:\Users\Junior\anaconda3\lib\site-packages\hvplot\converter.py in __init__(self, data, x, y, kind, by, use_index, group_label, value_label, backlog, persist, use_dask, crs, fields, groupby, dynamic, grid, legend, rot, title, xlim, ylim, clim, symmetric, logx, logy, loglog, hover, subplots, label, invert, stacked, colorbar, datashade, rasterize, row, col, debug, framewise, aggregator, projection, global_extent, geo, precompute, flip_xaxis, flip_yaxis, dynspread, hover_cols, x_sampling, y_sampling, project, tools, attr_labels, coastline, tiles, sort_date, check_symmetric_max, transforms, stream, cnorm, features, rescale_discrete_levels, **kwds)
#     386         self.dynamic = dynamic
#     387         self.geo = any([geo, crs, global_extent, projection, project, coastline, features])
# --> 388         self.crs = self._process_crs(data, crs) if self.geo else None
#     389         self.project = project
#     390         self.coastline = coastline
#
# c:\Users\Junior\anaconda3\lib\site-packages\hvplot\converter.py in _process_crs(self, data, crs)
#     628         _crs = getattr(data, 'attrs', {}).get(crs or 'crs', crs)
#     629         try:
# --> 630             return process_crs(_crs)
#     631         except ValueError:
#     632             # only raise error if crs was specified in kwargs
#
# c:\Users\Junior\anaconda3\lib\site-packages\hvplot\util.py in process_crs(crs)
#     234         import pyproj
#     235     except ImportError:
# --> 236         raise ImportError('Geographic projection support requires GeoViews and cartopy.')
#     237
#     238     if crs is None:
#
# ImportError: Geographic projection support requires GeoViews and cartopy.

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
# Narrow down cities that fit criteria and drop any results with null values
city_data_df = city_data_df.loc[(city_data_df["Max Temp"] >= 21) & (city_data_df["Max Temp"] < 24)]

# Drop any rows with null values
city_data_df = city_data_df.dropna(how='any')

# Display sample data
city_data_df.head()
# Out:
#     City_ID             City      Lat       Lng  Max Temp  Humidity  \
# 0         0             faya  18.3851   42.4509     22.06        35
# 9         9     saint-pierre -21.3393   55.4781     22.82        68
# 19       19     puerto ayora  -0.7393  -90.3518     22.98        82
# 20       20           avarua -21.2078 -159.7750     22.03        73
# 27       27  bambous virieux -20.3428   57.7575     22.14        68
#
#     Cloudiness  Wind Speed Country        Date
# 0           21        2.60      SA  1666108228
# 9            0        5.14      RE  1666108236
# 19          41        1.79      EC  1666108242
# 20          20        2.57      CK  1666108220
# 27          75        3.60      MU  1666108246

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity
hotel_df = city_data_df[["City","Country","Lat","Lng","Humidity"]].copy()

# Add an empty column, "Hotel Name," to the DataFrame so you can store the hotel found using the Geoapify API
hotel_df["Hotel Name"] = ""

# Display sample data
hotel_df.head()
# Out:
#                City Country      Lat       Lng  Humidity Hotel Name
# 0              faya      SA  18.3851   42.4509        35
# 9      saint-pierre      RE -21.3393   55.4781        68
# 19     puerto ayora      EC  -0.7393  -90.3518        82
# 20           avarua      CK -21.2078 -159.7750        73
# 27  bambous virieux      MU -20.3428   57.7575        68

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
radius = 10000
categories = 'accommodation.hotel'
limit = 1 

params = {
    "categories":categories,
    "limit":limit,
    "apiKey":geoapify_key
}


# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # get latitude, longitude from the DataFrame
    latitude = row['Lat']
    longitude = row['Lng']

    # Add filter and bias parameters with the current city's latitude and longitude to the params dictionary
    params["filter"] = f'circle:{longitude},{latitude},{radius}'
    params["bias"] = f'proximity:{longitude},{latitude}'
    
    # Set base URL
    base_url = "https://api.geoapify.com/v2/places"


    # Make and API request using the params dictionaty
    name_address = requests.get(base_url, params=params)
    
    # Convert the API response to JSON format
    name_address = name_address.json()
  
    
    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"
        
    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df
# Out:
# Starting hotel search
# faya - nearest hotel: No hotel found
# saint-pierre - nearest hotel: Tropic Hotel
# puerto ayora - nearest hotel: Hostal La Mirada De Solitario George
# avarua - nearest hotel: Paradise Inn
# bambous virieux - nearest hotel: Otentic Eco Tent Experience
# naberera - nearest hotel: No hotel found
# kapaa - nearest hotel: Pono Kai Resort
# lasa - nearest hotel: Hotel "Drei Kreuz"
# vaini - nearest hotel: Keleti International Resort
# east london - nearest hotel: No hotel found
# hermanus - nearest hotel: Aloe guest house
# mahebourg - nearest hotel: Grand Bel Air
# makakilo city - nearest hotel: Embassy Suites by Hilton Oahu Kapolei
# rafaela - nearest hotel: Toscano
# saint-philippe - nearest hotel: Le Baril
# muncar - nearest hotel: No hotel found
# peniche - nearest hotel: Residencial Maciel
# kahului - nearest hotel: Maui Seaside Hotel
# sembakung - nearest hotel: No hotel found
# grand gaube - nearest hotel: Coco Villa
# isangel - nearest hotel: Tanna Lodge
# port moresby - nearest hotel: The Sanctuary Hotel and Spa
# laguna - nearest hotel: Holiday Inn Express & Suites
# sao teotonio - nearest hotel: Case da Lupa
# yumbe - nearest hotel: Bayan Yumbe Hotel
# pangkalanbuun - nearest hotel: Hotel Tiara
# san cristobal - nearest hotel: Terra Sur
# makokou - nearest hotel: No hotel found
# rawson - nearest hotel: Hotel Deportivo
# tikaitnagar - nearest hotel: No hotel found
# quatre cocos - nearest hotel: Horisun
# camacha - nearest hotel: Praia Dourada
# san quintin - nearest hotel: Jardines Hotel
# jalu - nearest hotel: فندق جالو السياحي
# valdivia - nearest hotel: Esmeralda
# souillac - nearest hotel: Hotel SkylineInn
# tandil - nearest hotel: Viñas del Rosario Hotel Boutique
# vao - nearest hotel: Nataiwatch
# sambava - nearest hotel: Royal Sava Hôtel
# namibe - nearest hotel: Hotel Chik Chik Namibe
# viseu - nearest hotel: No hotel found
# kailua - nearest hotel: No hotel found
# mount isa - nearest hotel: Ibis Styles
# mahina - nearest hotel: Motu Martin
# saldanha - nearest hotel: Hoedjesbaai
# narwar - nearest hotel: No hotel found
# port hedland - nearest hotel: The Esplanade Hotel
# roebourne - nearest hotel: No hotel found
# saint-francois - nearest hotel: Chez Lily
# moron - nearest hotel: La Esquina
# muisne - nearest hotel: Hostal Té de Menta
# panuco - nearest hotel: Hotel Plaza
# fayaoue - nearest hotel: Hôtel Beaupré
# colares - nearest hotel: Hotel Arribas
# samandag - nearest hotel: Almina Apart Hotel
# dong hoi - nearest hotel: Nhà hàng Amor Palace
# vryburg - nearest hotel: International Hotel
# taitung - nearest hotel: 瑞軒民宿
# salto - nearest hotel: Hotel Español Salto
# kapit - nearest hotel: Haip
# bhandara - nearest hotel: Hotel Royal Plaza
# charters towers - nearest hotel: No hotel found
# guerrero negro - nearest hotel: Plaza sal paraiso
# bataipora - nearest hotel: Hotel Estoril
# chivilcoy - nearest hotel: Falcone
# ilhabela - nearest hotel: Vila Kebaya
# sangamner - nearest hotel: No hotel found
# poum - nearest hotel: No hotel found
#                 City Country      Lat       Lng  Humidity  \
# 0               faya      SA  18.3851   42.4509        35
# 9       saint-pierre      RE -21.3393   55.4781        68
# 19      puerto ayora      EC  -0.7393  -90.3518        82
# 20            avarua      CK -21.2078 -159.7750        73
# 27   bambous virieux      MU -20.3428   57.7575        68
# ..               ...     ...      ...       ...       ...
# 524        bataipora      BR -22.2953  -53.2711        89
# 531        chivilcoy      AR -34.8957  -60.0167        49
# 563         ilhabela      BR -23.7781  -45.3581        88
# 567        sangamner      IN  19.5667   74.2167        85
# 576             poum      NC -20.2333  164.0167        79
#
#                                Hotel Name
# 0                          No hotel found
# 9                            Tropic Hotel
# 19   Hostal La Mirada De Solitario George
# 20                           Paradise Inn
# 27            Otentic Eco Tent Experience
# ..                                    ...
# 524                         Hotel Estoril
# 531                               Falcone
# 563                           Vila Kebaya
# 567                        No hotel found
# 576                        No hotel found
#
# [68 rows x 6 columns]

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
# %%capture --no-display

# Configure the map plot
map_plot_2 = hotel_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    size = "Humidity",
    color = "City",
    scale = 1,
    tiles = "OSM",
    hover_cols = ['Hotel Name', 'Country']
)

# Display the map
map_plot_2
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# c:\Users\Junior\anaconda3\lib\site-packages\hvplot\util.py in process_crs(crs)
#     232         import cartopy.crs as ccrs
# --> 233         import geoviews as gv # noqa
#     234         import pyproj
#
# c:\Users\Junior\anaconda3\lib\site-packages\geoviews\__init__.py in <module>
#       8
# ----> 9 from .annotators import annotate # noqa (API import)
#      10 from .element import ( # noqa (API import)
#
# c:\Users\Junior\anaconda3\lib\site-packages\geoviews\annotators.py in <module>
#      14 from .links import VertexTableLink, PointTableLink, HvRectanglesTableLink, RectanglesTableLink
# ---> 15 from .operation import project
#      16 from .streams import PolyVertexDraw, PolyVertexEdit
#
# c:\Users\Junior\anaconda3\lib\site-packages\geoviews\operation\__init__.py in <module>
#       6 from ..element import _Element
# ----> 7 from .projection import ( # noqa (API import)
#       8     project_image, project_path, project_shape, project_points,
#
# c:\Users\Junior\anaconda3\lib\site-packages\geoviews\operation\projection.py in <module>
#      14
# ---> 15 from ..data import GeoPandasInterface
#      16 from ..element import (Image, Shape, Polygons, Path, Points, Contours,
#
# c:\Users\Junior\anaconda3\lib\site-packages\geoviews\data\__init__.py in <module>
#       1 from .geom_dict import GeomDictInterface # noqa (API import)
# ----> 2 from .geopandas import GeoPandasInterface # noqa (API import)
#       3 from .iris import CubeInterface # noqa (API import)
#
# c:\Users\Junior\anaconda3\lib\site-packages\geoviews\data\geopandas.py in <module>
#       9 from holoviews.core.util import isscalar, unique_iterator, unique_array
# ---> 10 from holoviews.core.data import Dataset, Interface, MultiInterface, PandasAPI
#      11 from holoviews.core.data.interface import DataError
#
# ImportError: cannot import name 'PandasAPI' from 'holoviews.core.data' (c:\Users\Junior\anaconda3\lib\site-packages\holoviews\core\data\__init__.py)
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13992\723467240.py in <module>
#       1 # Configure the map plot
# ----> 2 map_plot_2 = hotel_df.hvplot.points(
#       3     "Lng",
#       4     "Lat",
#       5     geo = True,
#
# c:\Users\Junior\anaconda3\lib\site-packages\hvplot\plotting\core.py in points(self, x, y, **kwds)
#     520             The HoloViews representation of the plot.
#     521         """
# --> 522         return self(x, y, kind='points', **kwds)
#     523
#     524     def vectorfield(self, x=None, y=None, angle=None, mag=None, **kwds):
#
# c:\Users\Junior\anaconda3\lib\site-packages\hvplot\plotting\core.py in __call__(self, x, y, kind, **kwds)
#      80                 return pn.panel(plot, **panel_dict)
#      81
# ---> 82         return self._get_converter(x, y, kind, **kwds)(kind, x, y)
#      83
#      84     def _get_converter(self, x=None, y=None, kind=None, **kwds):
#
# c:\Users\Junior\anaconda3\lib\site-packages\hvplot\plotting\core.py in _get_converter(self, x, y, kind, **kwds)
#      87         y = y or params.pop('y', None)
#      88         kind = kind or params.pop('kind', None)
# ---> 89         return HoloViewsConverter(
#      90             self._data, x, y, kind=kind, **params
#      91         )
#
# c:\Users\Junior\anaconda3\lib\site-packages\hvplot\converter.py in __init__(self, data, x, y, kind, by, use_index, group_label, value_label, backlog, persist, use_dask, crs, fields, groupby, dynamic, grid, legend, rot, title, xlim, ylim, clim, symmetric, logx, logy, loglog, hover, subplots, label, invert, stacked, colorbar, datashade, rasterize, row, col, debug, framewise, aggregator, projection, global_extent, geo, precompute, flip_xaxis, flip_yaxis, dynspread, hover_cols, x_sampling, y_sampling, project, tools, attr_labels, coastline, tiles, sort_date, check_symmetric_max, transforms, stream, cnorm, features, rescale_discrete_levels, **kwds)
#     386         self.dynamic = dynamic
#     387         self.geo = any([geo, crs, global_extent, projection, project, coastline, features])
# --> 388         self.crs = self._process_crs(data, crs) if self.geo else None
#     389         self.project = project
#     390         self.coastline = coastline
#
# c:\Users\Junior\anaconda3\lib\site-packages\hvplot\converter.py in _process_crs(self, data, crs)
#     628         _crs = getattr(data, 'attrs', {}).get(crs or 'crs', crs)
#     629         try:
# --> 630             return process_crs(_crs)
#     631         except ValueError:
#     632             # only raise error if crs was specified in kwargs
#
# c:\Users\Junior\anaconda3\lib\site-packages\hvplot\util.py in process_crs(crs)
#     234         import pyproj
#     235     except ImportError:
# --> 236         raise ImportError('Geographic projection support requires GeoViews and cartopy.')
#     237
#     238     if crs is None:
#
# ImportError: Geographic projection support requires GeoViews and cartopy.
