# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import scipy.stats as st

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 572

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?"
units = 'metric'

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city ################################
    city_url = f'{url}appid={weather_api_key}&units={units}&q={city}'
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url)
        data = city_weather.json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = data['coord']['lat']
        city_lng = data['coord']['lon']
        city_max_temp = data['main']['temp_max']
        city_humidity = data['main']['humidity']
        city_clouds = data['clouds']['all']
        city_wind = data['wind']['speed']
        city_country = data['sys']['country']
        city_date = data['dt']

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | crane
# Processing Record 2 of Set 1 | aconibe
# Processing Record 3 of Set 1 | lycksele
# Processing Record 4 of Set 1 | isla mujeres
# Processing Record 5 of Set 1 | colonia
# Processing Record 6 of Set 1 | luderitz
# Processing Record 7 of Set 1 | mahanoro
# Processing Record 8 of Set 1 | bethel
# Processing Record 9 of Set 1 | eyl
# Processing Record 10 of Set 1 | port-aux-francais
# Processing Record 11 of Set 1 | igarka
# Processing Record 12 of Set 1 | leua
# Processing Record 13 of Set 1 | ushuaia
# Processing Record 14 of Set 1 | grytviken
# Processing Record 15 of Set 1 | labrador city
# Processing Record 16 of Set 1 | cold lake
# Processing Record 17 of Set 1 | solnechnyy
# Processing Record 18 of Set 1 | geraldton
# Processing Record 19 of Set 1 | isafjordur
# Processing Record 20 of Set 1 | tazovsky
# Processing Record 21 of Set 1 | yellowknife
# Processing Record 22 of Set 1 | albany
# Processing Record 23 of Set 1 | 'ohonua
# City not found. Skipping...
# Processing Record 24 of Set 1 | tiksi
# Processing Record 25 of Set 1 | waitangi
# Processing Record 26 of Set 1 | adamstown
# Processing Record 27 of Set 1 | puerto baquerizo moreno
# Processing Record 28 of Set 1 | aegina
# Processing Record 29 of Set 1 | hawaiian paradise park
# Processing Record 30 of Set 1 | port elizabeth
# Processing Record 31 of Set 1 | punta arenas
# Processing Record 32 of Set 1 | olonkinbyen
# Processing Record 33 of Set 1 | saint-joseph
# Processing Record 34 of Set 1 | aliwal north
# Processing Record 35 of Set 1 | elliot lake
# Processing Record 36 of Set 1 | puerto san carlos
# City not found. Skipping...
# Processing Record 37 of Set 1 | ceerigaabo
# Processing Record 38 of Set 1 | hilo
# Processing Record 39 of Set 1 | st. john's
# Processing Record 40 of Set 1 | mar del plata
# Processing Record 41 of Set 1 | little cayman
# City not found. Skipping...
# Processing Record 42 of Set 1 | la ronge
# Processing Record 43 of Set 1 | saldanha
# Processing Record 44 of Set 1 | gaoual
# Processing Record 45 of Set 1 | pochinki
# Processing Record 46 of Set 1 | blackmans bay
# Processing Record 47 of Set 1 | knysna
# Processing Record 48 of Set 1 | college
# Processing Record 49 of Set 1 | abepura
# Processing Record 50 of Set 1 | askoy
# Processing Record 0 of Set 2 | wailua homesteads
# Processing Record 1 of Set 2 | salinopolis
# Processing Record 2 of Set 2 | aragarcas
# Processing Record 3 of Set 2 | utrik
# Processing Record 4 of Set 2 | sakakah
# Processing Record 5 of Set 2 | box elder
# Processing Record 6 of Set 2 | invercargill
# Processing Record 7 of Set 2 | vilyuchinsk
# Processing Record 8 of Set 2 | salmon arm
# Processing Record 9 of Set 2 | walvis bay
# Processing Record 10 of Set 2 | vilyuysk
# Processing Record 11 of Set 2 | anupgarh
# Processing Record 12 of Set 2 | bredasdorp
# Processing Record 13 of Set 2 | motilla del palancar
# Processing Record 14 of Set 2 | aykhal
# Processing Record 15 of Set 2 | bukama
# Processing Record 16 of Set 2 | port macquarie
# Processing Record 17 of Set 2 | port mathurin
# Processing Record 18 of Set 2 | san pedro pochutla
# Processing Record 19 of Set 2 | jamestown
# Processing Record 20 of Set 2 | tarnogskiy gorodok
# Processing Record 21 of Set 2 | pacific grove
# Processing Record 22 of Set 2 | longyearbyen
# Processing Record 23 of Set 2 | kodiak
# Processing Record 24 of Set 2 | udachny
# Processing Record 25 of Set 2 | pinotepa nacional
# Processing Record 26 of Set 2 | pisco
# Processing Record 27 of Set 2 | kokopo
# Processing Record 28 of Set 2 | sandnessjoen
# Processing Record 29 of Set 2 | babugarh
# Processing Record 30 of Set 2 | vingt cinq
# City not found. Skipping...
# Processing Record 31 of Set 2 | goz beida
# Processing Record 32 of Set 2 | iqaluit
# Processing Record 33 of Set 2 | lompoc
# Processing Record 34 of Set 2 | lihue
# Processing Record 35 of Set 2 | guiuan
# Processing Record 36 of Set 2 | ambalangoda
# Processing Record 37 of Set 2 | edinburgh of the seven seas
# Processing Record 38 of Set 2 | grants
# Processing Record 39 of Set 2 | taiohae
# City not found. Skipping...
# Processing Record 40 of Set 2 | peace river
# Processing Record 41 of Set 2 | oranjemund
# Processing Record 42 of Set 2 | puerto natales
# Processing Record 43 of Set 2 | port alfred
# Processing Record 44 of Set 2 | hotan
# Processing Record 45 of Set 2 | remire-montjoly
# Processing Record 46 of Set 2 | laguna
# Processing Record 47 of Set 2 | aasiaat
# Processing Record 48 of Set 2 | margaret river
# Processing Record 49 of Set 2 | zhalantun
# Processing Record 0 of Set 3 | ribeira grande
# Processing Record 1 of Set 3 | whitehorse
# Processing Record 2 of Set 3 | puerto ayora
# Processing Record 3 of Set 3 | alice springs
# Processing Record 4 of Set 3 | lospalos
# Processing Record 5 of Set 3 | san patricio
# Processing Record 6 of Set 3 | pionerskiy
# Processing Record 7 of Set 3 | kogalym
# Processing Record 8 of Set 3 | san luis de la loma
# Processing Record 9 of Set 3 | vorkuta
# Processing Record 10 of Set 3 | porto novo
# Processing Record 11 of Set 3 | port moresby
# Processing Record 12 of Set 3 | georgetown
# Processing Record 13 of Set 3 | hamilton
# Processing Record 14 of Set 3 | west island
# Processing Record 15 of Set 3 | happy valley-goose bay
# Processing Record 16 of Set 3 | ad dawadimi
# Processing Record 17 of Set 3 | dudinka
# Processing Record 18 of Set 3 | kerikeri
# Processing Record 19 of Set 3 | chandbali
# Processing Record 20 of Set 3 | atafu village
# Processing Record 21 of Set 3 | mount gambier
# Processing Record 22 of Set 3 | nar'yan-mar
# Processing Record 23 of Set 3 | papatowai
# Processing Record 24 of Set 3 | savanna-la-mar
# Processing Record 25 of Set 3 | sitka
# Processing Record 26 of Set 3 | chernyshevskiy
# Processing Record 27 of Set 3 | klyuchi
# Processing Record 28 of Set 3 | posse
# Processing Record 29 of Set 3 | genhe
# Processing Record 30 of Set 3 | kimbe
# Processing Record 31 of Set 3 | muhlhausen
# Processing Record 32 of Set 3 | abong mbang
# Processing Record 33 of Set 3 | seeb
# Processing Record 34 of Set 3 | pathein
# Processing Record 35 of Set 3 | danville
# Processing Record 36 of Set 3 | bara
# Processing Record 37 of Set 3 | herkimer
# Processing Record 38 of Set 3 | ha tinh
# Processing Record 39 of Set 3 | queenstown
# Processing Record 40 of Set 3 | ketchikan
# Processing Record 41 of Set 3 | port lincoln
# Processing Record 42 of Set 3 | east ballina
# Processing Record 43 of Set 3 | qaqortoq
# Processing Record 44 of Set 3 | la passe
# Processing Record 45 of Set 3 | villa mercedes
# Processing Record 46 of Set 3 | pembroke
# Processing Record 47 of Set 3 | maumere
# Processing Record 48 of Set 3 | rincon
# Processing Record 49 of Set 3 | ilulissat
# Processing Record 0 of Set 4 | vorgashor
# Processing Record 1 of Set 4 | tranovaho
# City not found. Skipping...
# Processing Record 2 of Set 4 | usogorsk
# Processing Record 3 of Set 4 | codrington
# Processing Record 4 of Set 4 | andalgala
# Processing Record 5 of Set 4 | tura
# Processing Record 6 of Set 4 | oxelosund
# Processing Record 7 of Set 4 | stanley
# Processing Record 8 of Set 4 | saint croix
# Processing Record 9 of Set 4 | saint-philippe
# Processing Record 10 of Set 4 | tolanaro
# Processing Record 11 of Set 4 | kahriz
# Processing Record 12 of Set 4 | nemuro
# Processing Record 13 of Set 4 | mangrol
# Processing Record 14 of Set 4 | talcahuano
# Processing Record 15 of Set 4 | puerto asis
# Processing Record 16 of Set 4 | thompson
# Processing Record 17 of Set 4 | sajir
# Processing Record 18 of Set 4 | ladario
# Processing Record 19 of Set 4 | yangiobod
# Processing Record 20 of Set 4 | soma
# Processing Record 21 of Set 4 | uturoa
# Processing Record 22 of Set 4 | bilibino
# Processing Record 23 of Set 4 | larvik
# Processing Record 24 of Set 4 | port glaud
# City not found. Skipping...
# Processing Record 25 of Set 4 | guerrero negro
# Processing Record 26 of Set 4 | kerch
# Processing Record 27 of Set 4 | tamanrasset
# Processing Record 28 of Set 4 | fuvahmulah
# City not found. Skipping...
# Processing Record 29 of Set 4 | pitanga
# Processing Record 30 of Set 4 | rufino
# Processing Record 31 of Set 4 | orchard homes
# Processing Record 32 of Set 4 | kroya
# Processing Record 33 of Set 4 | colonia menno
# Processing Record 34 of Set 4 | kayangel
# Processing Record 35 of Set 4 | carnarvon
# Processing Record 36 of Set 4 | ancud
# Processing Record 37 of Set 4 | coxim
# Processing Record 38 of Set 4 | cannonvale
# Processing Record 39 of Set 4 | kenora
# Processing Record 40 of Set 4 | ararat
# Processing Record 41 of Set 4 | kendari
# Processing Record 42 of Set 4 | zeya
# Processing Record 43 of Set 4 | santiago de cao
# Processing Record 44 of Set 4 | douglas
# Processing Record 45 of Set 4 | zhezqazghan
# Processing Record 46 of Set 4 | lethem
# Processing Record 47 of Set 4 | berezovyy
# Processing Record 48 of Set 4 | polyarnyy
# Processing Record 49 of Set 4 | lata
# Processing Record 0 of Set 5 | zijinglu
# Processing Record 1 of Set 5 | lagos
# Processing Record 2 of Set 5 | galle
# Processing Record 3 of Set 5 | brookings
# Processing Record 4 of Set 5 | taulaga
# Processing Record 5 of Set 5 | broken hill
# Processing Record 6 of Set 5 | badger
# Processing Record 7 of Set 5 | alamos
# Processing Record 8 of Set 5 | salavan
# Processing Record 9 of Set 5 | suva
# Processing Record 10 of Set 5 | praia da vitoria
# Processing Record 11 of Set 5 | kuanda
# Processing Record 12 of Set 5 | sisimiut
# Processing Record 13 of Set 5 | petropavlovsk-kamchatsky
# Processing Record 14 of Set 5 | pundong
# Processing Record 15 of Set 5 | hermanus
# Processing Record 16 of Set 5 | lure
# Processing Record 17 of Set 5 | arraial do cabo
# Processing Record 18 of Set 5 | shanhaiguan
# Processing Record 19 of Set 5 | aur
# Processing Record 20 of Set 5 | iskateley
# Processing Record 21 of Set 5 | prien
# Processing Record 22 of Set 5 | sinop
# Processing Record 23 of Set 5 | santiago papasquiaro
# City not found. Skipping...
# Processing Record 24 of Set 5 | noosa heads
# Processing Record 25 of Set 5 | sao joao da barra
# Processing Record 26 of Set 5 | harper
# Processing Record 27 of Set 5 | cooper's town
# Processing Record 28 of Set 5 | afaahiti
# Processing Record 29 of Set 5 | saipan
# Processing Record 30 of Set 5 | thomaston
# Processing Record 31 of Set 5 | burang
# Processing Record 32 of Set 5 | campo grande
# Processing Record 33 of Set 5 | mont-laurier
# Processing Record 34 of Set 5 | punta alta
# Processing Record 35 of Set 5 | canmore
# Processing Record 36 of Set 5 | yendi
# Processing Record 37 of Set 5 | bathsheba
# Processing Record 38 of Set 5 | kingston
# Processing Record 39 of Set 5 | nadym
# Processing Record 40 of Set 5 | nelson
# Processing Record 41 of Set 5 | fort stockton
# Processing Record 42 of Set 5 | holualoa
# Processing Record 43 of Set 5 | fortuna
# Processing Record 44 of Set 5 | talnakh
# Processing Record 45 of Set 5 | roma
# Processing Record 46 of Set 5 | cabo san lucas
# Processing Record 47 of Set 5 | ilare
# Processing Record 48 of Set 5 | kristiansund
# Processing Record 49 of Set 5 | maun
# Processing Record 0 of Set 6 | ko pha ngan
# Processing Record 1 of Set 6 | yorkton
# Processing Record 2 of Set 6 | weno
# Processing Record 3 of Set 6 | ouellah
# City not found. Skipping...
# Processing Record 4 of Set 6 | karasuk
# Processing Record 5 of Set 6 | ust-nera
# Processing Record 6 of Set 6 | norrtalje
# Processing Record 7 of Set 6 | xuddur
# Processing Record 8 of Set 6 | demyansk
# Processing Record 9 of Set 6 | kaohsiung
# Processing Record 10 of Set 6 | lebu
# Processing Record 11 of Set 6 | manggar
# Processing Record 12 of Set 6 | gummi
# Processing Record 13 of Set 6 | villa gesell
# Processing Record 14 of Set 6 | swan hill
# Processing Record 15 of Set 6 | al jawf
# Processing Record 16 of Set 6 | mata-utu
# Processing Record 17 of Set 6 | yuzhno-kurilsk
# Processing Record 18 of Set 6 | saint-francois
# Processing Record 19 of Set 6 | namibe
# Processing Record 20 of Set 6 | tozeur
# Processing Record 21 of Set 6 | namsos
# Processing Record 22 of Set 6 | leeton
# Processing Record 23 of Set 6 | avarua
# Processing Record 24 of Set 6 | bam
# Processing Record 25 of Set 6 | hithadhoo
# Processing Record 26 of Set 6 | mukalla
# Processing Record 27 of Set 6 | kiunga
# Processing Record 28 of Set 6 | saudarkrokur
# Processing Record 29 of Set 6 | vizinga
# Processing Record 30 of Set 6 | gaiman
# Processing Record 31 of Set 6 | kirovskiy
# Processing Record 32 of Set 6 | palangkaraya
# Processing Record 33 of Set 6 | corinto
# Processing Record 34 of Set 6 | hobyo
# Processing Record 35 of Set 6 | tefe
# Processing Record 36 of Set 6 | isle of lewis
# City not found. Skipping...
# Processing Record 37 of Set 6 | north bend
# Processing Record 38 of Set 6 | ishigaki
# Processing Record 39 of Set 6 | port blair
# Processing Record 40 of Set 6 | nishinoomote
# Processing Record 41 of Set 6 | ingeniero jacobacci
# Processing Record 42 of Set 6 | nova sintra
# Processing Record 43 of Set 6 | juruti
# Processing Record 44 of Set 6 | wamba
# Processing Record 45 of Set 6 | carahue
# Processing Record 46 of Set 6 | manokwari
# Processing Record 47 of Set 6 | enewetak
# Processing Record 48 of Set 6 | neon karlovasion
# Processing Record 49 of Set 6 | rikaze
# Processing Record 0 of Set 7 | dampit
# Processing Record 1 of Set 7 | touros
# Processing Record 2 of Set 7 | markala
# Processing Record 3 of Set 7 | berdigestyakh
# Processing Record 4 of Set 7 | veraval
# Processing Record 5 of Set 7 | lucapa
# Processing Record 6 of Set 7 | alaghsas
# Processing Record 7 of Set 7 | taltal
# Processing Record 8 of Set 7 | howrah
# Processing Record 9 of Set 7 | estevan
# Processing Record 10 of Set 7 | kota belud
# Processing Record 11 of Set 7 | lardjem
# Processing Record 12 of Set 7 | guymon
# Processing Record 13 of Set 7 | howard springs
# Processing Record 14 of Set 7 | minas de marcona
# Processing Record 15 of Set 7 | anadyr
# Processing Record 16 of Set 7 | songea
# Processing Record 17 of Set 7 | onega
# Processing Record 18 of Set 7 | nagqu
# Processing Record 19 of Set 7 | east london
# Processing Record 20 of Set 7 | andergrove
# Processing Record 21 of Set 7 | alotau
# City not found. Skipping...
# Processing Record 22 of Set 7 | colares
# Processing Record 23 of Set 7 | pocahontas
# Processing Record 24 of Set 7 | yamada
# Processing Record 25 of Set 7 | quellon
# Processing Record 26 of Set 7 | karungdong
# Processing Record 27 of Set 7 | perry
# Processing Record 28 of Set 7 | vila franca do campo
# Processing Record 29 of Set 7 | lerwick
# Processing Record 30 of Set 7 | fonadhoo
# City not found. Skipping...
# Processing Record 31 of Set 7 | lazaro cardenas
# Processing Record 32 of Set 7 | santa cruz
# Processing Record 33 of Set 7 | kupang
# Processing Record 34 of Set 7 | illizi
# Processing Record 35 of Set 7 | thoen
# Processing Record 36 of Set 7 | baiti
# Processing Record 37 of Set 7 | kapuskasing
# Processing Record 38 of Set 7 | cockburn town
# Processing Record 39 of Set 7 | xiantao
# Processing Record 40 of Set 7 | nampula
# Processing Record 41 of Set 7 | as sulayyil
# Processing Record 42 of Set 7 | jalai nur
# Processing Record 43 of Set 7 | ta`u
# Processing Record 44 of Set 7 | kanker
# Processing Record 45 of Set 7 | riohacha
# Processing Record 46 of Set 7 | nueva gerona
# Processing Record 47 of Set 7 | freetown
# Processing Record 48 of Set 7 | ubinskoye
# Processing Record 49 of Set 7 | duong dong
# Processing Record 0 of Set 8 | kulia village
# City not found. Skipping...
# Processing Record 1 of Set 8 | vershino-darasunskiy
# Processing Record 2 of Set 8 | greymouth
# Processing Record 3 of Set 8 | argo
# Processing Record 4 of Set 8 | kharp
# Processing Record 5 of Set 8 | boyolangu
# Processing Record 6 of Set 8 | susuman
# Processing Record 7 of Set 8 | paramirim
# Processing Record 8 of Set 8 | haiku-pauwela
# Processing Record 9 of Set 8 | salalah
# Processing Record 10 of Set 8 | horta
# Processing Record 11 of Set 8 | kavieng
# Processing Record 12 of Set 8 | fale old settlement
# Processing Record 13 of Set 8 | marka
# Processing Record 14 of Set 8 | worland
# Processing Record 15 of Set 8 | yaita
# Processing Record 16 of Set 8 | monteagudo
# Processing Record 17 of Set 8 | buka
# Processing Record 18 of Set 8 | childress
# Processing Record 19 of Set 8 | vadso
# Processing Record 20 of Set 8 | selfoss
# Processing Record 21 of Set 8 | inari
# Processing Record 22 of Set 8 | bucerias
# Processing Record 23 of Set 8 | felidhoo
# City not found. Skipping...
# Processing Record 24 of Set 8 | gadzhiyevo
# Processing Record 25 of Set 8 | playa del ingles
# Processing Record 26 of Set 8 | joanopolis
# Processing Record 27 of Set 8 | azhikkal
# Processing Record 28 of Set 8 | chimoio
# Processing Record 29 of Set 8 | harstad
# Processing Record 30 of Set 8 | rakops
# Processing Record 31 of Set 8 | suai
# City not found. Skipping...
# Processing Record 32 of Set 8 | noumea
# Processing Record 33 of Set 8 | khamis mushait
# Processing Record 34 of Set 8 | bismarck
# Processing Record 35 of Set 8 | hammerfest
# Processing Record 36 of Set 8 | lorengau
# Processing Record 37 of Set 8 | saint-denis
# Processing Record 38 of Set 8 | tari
# Processing Record 39 of Set 8 | okha
# Processing Record 40 of Set 8 | grande prairie
# Processing Record 41 of Set 8 | awjilah
# Processing Record 42 of Set 8 | leh
# Processing Record 43 of Set 8 | meadow lake
# Processing Record 44 of Set 8 | hinton
# Processing Record 45 of Set 8 | prado
# Processing Record 46 of Set 8 | juegang
# Processing Record 47 of Set 8 | gamay
# Processing Record 48 of Set 8 | port augusta
# Processing Record 49 of Set 8 | xiuyan
# Processing Record 0 of Set 9 | nichinan
# Processing Record 1 of Set 9 | yagry
# City not found. Skipping...
# Processing Record 2 of Set 9 | bartlesville
# Processing Record 3 of Set 9 | dakhla
# Processing Record 4 of Set 9 | portland
# Processing Record 5 of Set 9 | mitu
# Processing Record 6 of Set 9 | deqen
# Processing Record 7 of Set 9 | whistler
# Processing Record 8 of Set 9 | east end
# Processing Record 9 of Set 9 | korets
# Processing Record 10 of Set 9 | santa ana de yacuma
# Processing Record 11 of Set 9 | ilebo
# Processing Record 12 of Set 9 | kirakira
# Processing Record 13 of Set 9 | inirida
# Processing Record 14 of Set 9 | leskova dolina
# Processing Record 15 of Set 9 | honefoss
# Processing Record 16 of Set 9 | parit raja
# Processing Record 17 of Set 9 | general mosconi
# Processing Record 18 of Set 9 | bayramaly
# Processing Record 19 of Set 9 | sulphur
# Processing Record 20 of Set 9 | al ain city
# Processing Record 21 of Set 9 | merida
# Processing Record 22 of Set 9 | san antonio de pale
# Processing Record 23 of Set 9 | katsuura
# Processing Record 24 of Set 9 | rajapur
# Processing Record 25 of Set 9 | aksu
# Processing Record 26 of Set 9 | elmendorf air force base
# City not found. Skipping...
# Processing Record 27 of Set 9 | qarqaraly
# Processing Record 28 of Set 9 | tsiombe
# Processing Record 29 of Set 9 | loen
# Processing Record 30 of Set 9 | qashyr
# Processing Record 31 of Set 9 | dakoutun
# Processing Record 32 of Set 9 | acarau
# Processing Record 33 of Set 9 | mandal
# Processing Record 34 of Set 9 | isabela
# Processing Record 35 of Set 9 | yelovo
# Processing Record 36 of Set 9 | kargasok
# Processing Record 37 of Set 9 | al hudaydah
# Processing Record 38 of Set 9 | jaguaruna
# Processing Record 39 of Set 9 | yeongam
# City not found. Skipping...
# Processing Record 40 of Set 9 | swakopmund
# Processing Record 41 of Set 9 | rongelap
# Processing Record 42 of Set 9 | christchurch
# Processing Record 43 of Set 9 | grand baie
# Processing Record 44 of Set 9 | shimoda
# Processing Record 45 of Set 9 | cudillero
# Processing Record 46 of Set 9 | oxapampa
# Processing Record 47 of Set 9 | janeng
# Processing Record 48 of Set 9 | siwa oasis
# Processing Record 49 of Set 9 | kapa'a
# Processing Record 0 of Set 10 | eforie sud
# Processing Record 1 of Set 10 | zaozersk
# Processing Record 2 of Set 10 | nuku'alofa
# Processing Record 3 of Set 10 | amga
# Processing Record 4 of Set 10 | novodvinsk
# Processing Record 5 of Set 10 | new norfolk
# Processing Record 6 of Set 10 | san jose village
# City not found. Skipping...
# Processing Record 7 of Set 10 | kataragama
# City not found. Skipping...
# Processing Record 8 of Set 10 | asbe teferi
# Processing Record 9 of Set 10 | wanning
# Processing Record 10 of Set 10 | itoman
# Processing Record 11 of Set 10 | coquimbo
# Processing Record 12 of Set 10 | bodo
# Processing Record 13 of Set 10 | cam ranh
# Processing Record 14 of Set 10 | rio grande
# Processing Record 15 of Set 10 | laojunmiao
# Processing Record 16 of Set 10 | campbellton
# Processing Record 17 of Set 10 | el nido
# Processing Record 18 of Set 10 | barra de santo antonio
# Processing Record 19 of Set 10 | livingston
# Processing Record 20 of Set 10 | santarem
# Processing Record 21 of Set 10 | fort bragg
# Processing Record 22 of Set 10 | lashio
# Processing Record 23 of Set 10 | guixi
# Processing Record 24 of Set 10 | kudahuvadhoo
# Processing Record 25 of Set 10 | spassk-ryazanskiy
# Processing Record 26 of Set 10 | tangzhai
# Processing Record 27 of Set 10 | magadan
# Processing Record 28 of Set 10 | puerto san jose
# Processing Record 29 of Set 10 | hayma'
# City not found. Skipping...
# Processing Record 30 of Set 10 | kota kinabalu
# Processing Record 31 of Set 10 | qal'at bishah
# City not found. Skipping...
# Processing Record 32 of Set 10 | pahrump
# Processing Record 33 of Set 10 | haffouz
# Processing Record 34 of Set 10 | taroa
# Processing Record 35 of Set 10 | saint-felicien
# Processing Record 36 of Set 10 | twon-brass
# Processing Record 37 of Set 10 | markaz-e hukumat-e darweshan
# Processing Record 38 of Set 10 | montepuez
# Processing Record 39 of Set 10 | demirci
# Processing Record 40 of Set 10 | oriximina
# Processing Record 41 of Set 10 | al bardiyah
# Processing Record 42 of Set 10 | forestdale
# Processing Record 43 of Set 10 | hovd
# Processing Record 44 of Set 10 | den burg
# Processing Record 45 of Set 10 | loushanguan
# Processing Record 46 of Set 10 | luganville
# Processing Record 47 of Set 10 | srikakulam
# Processing Record 48 of Set 10 | kuraymah
# Processing Record 49 of Set 10 | viedma
# Processing Record 0 of Set 11 | vernon
# Processing Record 1 of Set 11 | neiafu
# Processing Record 2 of Set 11 | papao
# Processing Record 3 of Set 11 | shache
# Processing Record 4 of Set 11 | bilmak
# Processing Record 5 of Set 11 | shendi
# Processing Record 6 of Set 11 | castillos
# Processing Record 7 of Set 11 | inekar
# City not found. Skipping...
# Processing Record 8 of Set 11 | tobruk
# Processing Record 9 of Set 11 | gobabis
# Processing Record 10 of Set 11 | nizhniy odes
# Processing Record 11 of Set 11 | quezon
# Processing Record 12 of Set 11 | choix
# Processing Record 13 of Set 11 | san jose de jachal
# Processing Record 14 of Set 11 | dhidhdhoo
# Processing Record 15 of Set 11 | shohimardon
# Processing Record 16 of Set 11 | strezhevoy
# Processing Record 17 of Set 11 | mananjary
# Processing Record 18 of Set 11 | xilin hot
# Processing Record 19 of Set 11 | antalaha
# Processing Record 20 of Set 11 | alpena
# Processing Record 21 of Set 11 | ondjiva
# Processing Record 22 of Set 11 | ardestan
# Processing Record 23 of Set 11 | inarajan village
# Processing Record 24 of Set 11 | ulladulla
# Processing Record 25 of Set 11 | el calafate
# Processing Record 26 of Set 11 | tazacorte
# Processing Record 27 of Set 11 | hasaki
# Processing Record 28 of Set 11 | tanda
# Processing Record 29 of Set 11 | adilcevaz
# Processing Record 30 of Set 11 | poronaysk
# Processing Record 31 of Set 11 | mafinga
# Processing Record 32 of Set 11 | cambria
# Processing Record 33 of Set 11 | tres isletas
# Processing Record 34 of Set 11 | santuario
# Processing Record 35 of Set 11 | sinabang
# Processing Record 36 of Set 11 | sungailiat
# Processing Record 37 of Set 11 | ola
# Processing Record 38 of Set 11 | loango
# Processing Record 39 of Set 11 | ceeldheer
# Processing Record 40 of Set 11 | valparaiso
# Processing Record 41 of Set 11 | constantia
# Processing Record 42 of Set 11 | chonchi
# Processing Record 43 of Set 11 | antofagasta
# Processing Record 44 of Set 11 | bereznik
# Processing Record 45 of Set 11 | keflavik
# Processing Record 46 of Set 11 | ryazan'
# Processing Record 47 of Set 11 | barbastro
# Processing Record 48 of Set 11 | legnago
# Processing Record 49 of Set 11 | at tall al kabir
# Processing Record 0 of Set 12 | hinesville
# Processing Record 1 of Set 12 | taro
# Processing Record 2 of Set 12 | cururupu
# Processing Record 3 of Set 12 | luwuk
# Processing Record 4 of Set 12 | quang ngai
# Processing Record 5 of Set 12 | cabedelo
# Processing Record 6 of Set 12 | kavaratti
# Processing Record 7 of Set 12 | embi
# Processing Record 8 of Set 12 | riviere-du-loup
# Processing Record 9 of Set 12 | gagliano del capo
# Processing Record 10 of Set 12 | beruniy
# Processing Record 11 of Set 12 | winnemucca
# Processing Record 12 of Set 12 | flying fish cove
# Processing Record 13 of Set 12 | illela
# Processing Record 14 of Set 12 | tyuratam
# Processing Record 15 of Set 12 | upper hutt
# Processing Record 16 of Set 12 | duba
# Processing Record 17 of Set 12 | villa union
# Processing Record 18 of Set 12 | la foa
# Processing Record 19 of Set 12 | dodge city
# Processing Record 20 of Set 12 | minot
# Processing Record 21 of Set 12 | mozarlandia
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          548
# Lat           548
# Lng           548
# Max Temp      548
# Humidity      548
# Cloudiness    548
# Wind Speed    548
# Country       548
# Date          548
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         crane  31.3974 -102.3501     31.63        32          12
# 1       aconibe   1.2968   10.9369     20.39        97         100
# 2      lycksele  64.5954   18.6735     21.35        55          98
# 3  isla mujeres  21.2311  -86.7310     29.03        82           0
# 4       colonia  50.9333    6.9500     20.97        81          40
#
#    Wind Speed Country        Date
# 0        4.11      US  1687240005
# 1        0.50      GQ  1687240005
# 2        1.03      SE  1687240005
# 3        5.14      MX  1687240006
# 4        1.54      DE  1687240006

# %%
# Export the City_Data into a csv
city_data_df.to_csv("../output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("../output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0               crane  31.3974 -102.3501     31.63        32          12
# 1             aconibe   1.2968   10.9369     20.39        97         100
# 2            lycksele  64.5954   18.6735     21.35        55          98
# 3        isla mujeres  21.2311  -86.7310     29.03        82           0
# 4             colonia  50.9333    6.9500     20.97        81          40
#
#          Wind Speed Country        Date
# City_ID
# 0              4.11      US  1687240005
# 1              0.50      GQ  1687240005
# 2              1.03      SE  1687240005
# 3              5.14      MX  1687240006
# 4              1.54      DE  1687240006

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
x_values = city_data_df['Lat']
y_values = city_data_df['Max Temp']
plt.scatter(x_values,y_values)

# Incorporate the other graph properties
plt.xlabel('Latitude')
plt.ylabel('Max Temperature')
plt.title('City Max Latitude vs. Temperature')

# Save the figure
plt.savefig("../output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
x_values = city_data_df['Lat']
humidity = city_data_df['Humidity']
plt.scatter(x_values,humidity)

# Incorporate the other graph properties
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.title('City Latitude vs. Humidity')

# Save the figure
plt.savefig("../output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
x_values = city_data_df['Lat']
clouds = city_data_df['Cloudiness']
plt.scatter(x_values,clouds)

# Incorporate the other graph properties
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.title('City Latitude vs. Cloudiness')

# Save the figure
plt.savefig("../output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
x_values = city_data_df['Lat']
wind = city_data_df['Wind Speed']
plt.scatter(x_values, wind)

# Incorporate the other graph properties
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.title('City Latitude vs. Wind Speed')

# Save the figure
plt.savefig("../output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_values, y_values)
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
regress_values = x_values * slope + intercept
print(line_eq)
# Out:
# y = 0.01x +20.32

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df[city_data_df['Lat'] >= 0] 

# Display sample data
northern_hemi_df.head()
# Out:
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0               crane  31.3974 -102.3501     31.63        32          12
# 1             aconibe   1.2968   10.9369     20.39        97         100
# 2            lycksele  64.5954   18.6735     21.35        55          98
# 3        isla mujeres  21.2311  -86.7310     29.03        82           0
# 4             colonia  50.9333    6.9500     20.97        81          40
#
#          Wind Speed Country        Date
# City_ID
# 0              4.11      US  1687240005
# 1              0.50      GQ  1687240005
# 2              1.03      SE  1687240005
# 3              5.14      MX  1687240006
# 4              1.54      DE  1687240006

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df[city_data_df['Lat'] < 0]

# Display sample data
southern_hemi_df.head()
# Out:
#                       City      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 5                 luderitz -26.6481  15.1594     11.37        78          14
# 6                 mahanoro -19.9000  48.8000     22.57        57         100
# 9        port-aux-francais -49.3500  70.2167      3.67        65          50
# 12                 ushuaia -54.8000 -68.3000      3.81        60           0
# 13               grytviken -54.2811 -36.5092     -0.51        86          54
#
#          Wind Speed Country        Date
# City_ID
# 5              6.16     NaN  1687240006
# 6              0.55      MG  1687240006
# 9             10.86      TF  1687240006
# 12             1.54      AR  1687239821
# 13             4.52      GS  1687240007

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Max Temp']

(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values, y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(5.8,-30),fontsize=15,color="blue")
plt.xlabel('Latitude')
plt.ylabel('Temperature')
plt.show()

# %%
# Linear regression on Southern Hemisphere
z_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Max Temp']


(slope, intercept, rvalue, pvalue, stderr) = st.linregress(z_values, y_values)
regress_values = z_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(z_values, y_values)
plt.plot(z_values,regress_values,"r-")
plt.annotate(line_eq,(-50,35),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temp')
plt.show()

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Humidity']

(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))




plt.scatter(x_values, y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(40,20),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.show()

# %%
# Southern Hemisphere
south_lat = southern_hemi_df['Lat']
south_humid = southern_hemi_df['Humidity']


(slope, intercept, rvalue, pvalue, stderr) = st.linregress(south_lat, south_humid)
regress_values = south_lat * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(south_lat, south_humid)
plt.plot(south_lat,regress_values,"r-")
plt.annotate(line_eq,(-55,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.show()

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Cloudiness']

(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values, y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(50,0.8),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.show()

# %%
# Southern Hemisphere
south_lat = southern_hemi_df['Lat']
south_clouds = southern_hemi_df['Cloudiness']

(slope, intercept, rvalue, pvalue, stderr) = st.linregress(south_lat, south_clouds)
regress_values = south_lat * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(south_lat, south_clouds)
plt.plot(south_lat,regress_values,"r-")
plt.annotate(line_eq,(-55,60),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.show()

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
north_lat = northern_hemi_df['Lat']
north_wind = northern_hemi_df['Wind Speed']


(slope, intercept, rvalue, pvalue, stderr) = st.linregress(north_lat, north_wind)
regress_values = north_lat * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(north_lat, north_wind)
plt.plot(north_lat,regress_values,"r-")
plt.annotate(line_eq,(0,12),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.show()

# %%
# Southern Hemisphere
south_wind = southern_hemi_df['Wind Speed']


(slope, intercept, rvalue, pvalue, stderr) = st.linregress(south_lat, south_wind)
regress_values = south_lat * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(south_lat, south_wind)
plt.plot(south_lat,regress_values,"r-")
plt.annotate(line_eq,(-25,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.show()

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
